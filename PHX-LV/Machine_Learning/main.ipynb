# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

def load_data(directory, file_name):
    file_path = os.path.join(directory, file_name)
    print(f"Loading data from {file_path}")
    return pd.read_csv(file_path)

def build_model(input_shape, output_shape):     # Has to be implemented
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(output_shape)
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

def train_model(model, X_train, y_train, X_test, y_test):     # Has to be implemented
    model.fit(X_train, y_train, epochs=100, batch_size=34, validation_data=(X_test, y_test))

def evaluate_model(model, X_test, y_test):                  # Has to be implemented
    loss, mae = model.evaluate(X_test, y_test)
    print(f'Test Loss: {loss}, Test MAE: {mae}')


def get_file_pairs(directory):
    flight_files = []
    waypoint_files = []

    for file_name in os.listdir(directory):
        if file_name.endswith(".csv"):
            if "WAYPOINTS" in file_name:
                waypoint_files.append(file_name)
            else:
                flight_files.append(file_name)

    return sorted(flight_files), sorted(waypoint_files)

# Load flight and waypoint data directories
waypoint_data_dir = "scraped_waypoints_KPHX_KLAS"
flight_data_dir = "scraped_data_KPHX_KLAS"

# List flight and waypoint files
waypoint_files = sorted(os.listdir(waypoint_data_dir))
flight_files = sorted(os.listdir(flight_data_dir))

print("Waypoint Files:", waypoint_files)
print("Flight Files:", flight_files)

# Process each pair of flight and waypoint files
for flight_file, waypoint_file in zip(flight_files, waypoint_files):
    print(f"Processing {flight_file} and {waypoint_file}...")

    # Load flight data and waypoints
    flight_data = load_data(flight_data_dir, flight_file)
    waypoints = load_data(waypoint_data_dir, waypoint_file)

    print("Flight Data:")
    print(flight_data.head())

    print("Waypoints:")
    print(waypoints.head())

    # Drop rows with NaN values in 'Time (EST)' and 'feet' columns
    flight_data.dropna(subset=['Time (EST)', 'feet'], inplace=True)
    
    # Convert 'feet' column to strings
    flight_data['feet_str'] = flight_data['feet'].astype(str)
    
    print(flight_data.head())
    
    # Convert 'feet' column to numeric
    flight_data['feet'] = flight_data['feet'].str.replace(',', '').astype(float)
    
    # Convert 'Time (EST)' column to datetime format with explicit format
    flight_data['Time (EST)'] = pd.to_datetime(flight_data['Time (EST)'], format='%a %H:%M:%S %p')
    
    # Extract hour and minute components from the 'Time (EST)' column in 24-hour format
    flight_data['Hour_Minute'] = flight_data['Time (EST)'].dt.strftime('%H:%M')
    
    print("Original Flight Altitude vs Time graph: ")
    # Plot altitude vs time using a line plot
    plt.figure(figsize=(10, 5))
    plt.plot(flight_data['Hour_Minute'], flight_data['feet'], color='blue')
    plt.title('Altitude vs Time')
    plt.xlabel('Time of the Day (Hour:Minute)')
    plt.ylabel('Altitude (feet)')
    plt.grid(True)
    plt.show()
    
    # Plot Latitude vs Longitude using a line plot
    plt.figure(figsize=(5, 5))
    plt.plot(waypoints['Latitude'], waypoints['Longitude'], color='red')
    plt.title('Latitude vs Longitude')
    plt.xlabel('Longitude (Degrees)')
    plt.ylabel('Latitude (Degrees)')
    plt.grid(True)
    plt.show()
# Out:
# Waypoint Files: ['Fri0213PMMST_A20N_WAYPOINTS.csv', 'Fri0305PMMST_B738_WAYPOINTS.csv', 'Fri0313PMMST_A321_WAYPOINTS.csv', 'Fri0710AMMST_B737_WAYPOINTS.csv', 'Fri0800AMMST_CL60_WAYPOINTS.csv', 'Fri0820AMMST_B738_WAYPOINTS.csv', 'Fri0825AMMST_A21N_WAYPOINTS.csv', 'Fri0910AMMST_B738_WAYPOINTS.csv', 'Fri0915AMMST_SH36_WAYPOINTS.csv', 'Fri1015AMMST_B38M_WAYPOINTS.csv', 'Fri1140AMMST_B38M_WAYPOINTS.csv', 'Fri1152AMMST_B38M_WAYPOINTS.csv', 'Fri1255PMMST_B38M_WAYPOINTS.csv', 'Thu0100PMMST_B738_WAYPOINTS.csv', 'Thu0230PMMST_A20N_WAYPOINTS.csv', 'Thu0305PMMST_B738_WAYPOINTS.csv', 'Thu0313PMMST_A321_WAYPOINTS.csv', 'Thu0430PMMST_A319_WAYPOINTS.csv', 'Thu0510PMMST_B738_WAYPOINTS.csv', 'Thu0530PMMST_A319_WAYPOINTS.csv', 'Thu0615PMMST_B737_WAYPOINTS.csv', 'Thu0619PMMST_B38M_WAYPOINTS.csv', 'Thu0636PMMST_A20N_WAYPOINTS.csv', 'Thu0715AMMST_B737_WAYPOINTS.csv', 'Thu0736PMMST_C56X_WAYPOINTS.csv', 'Thu0750PMMST_B737_WAYPOINTS.csv', 'Thu0820AMMST_B38M_WAYPOINTS.csv', 'Thu0825AMMST_A21N_WAYPOINTS.csv', 'Thu0910AMMST_B738_WAYPOINTS.csv', 'Thu0915AMMST_SH36_WAYPOINTS.csv', 'Thu0930PMMST_B738_WAYPOINTS.csv', 'Thu0940PMMST_A21N_WAYPOINTS.csv', 'Thu0945PMMST_A20N_WAYPOINTS.csv', 'Thu1015AMMST_B738_WAYPOINTS.csv', 'Thu1140AMMST_B38M_WAYPOINTS.csv', 'Thu1152AMMST_B38M_WAYPOINTS.csv', 'Thu1210AMMST_B738_WAYPOINTS.csv', 'Thu1211PMMST_A20N_WAYPOINTS.csv']
# Flight Files: ['Fri0213PMMST_A20N.csv', 'Fri0305PMMST_B738.csv', 'Fri0313PMMST_A321.csv', 'Fri0510PMMST_B38M.csv', 'Fri0527PMMST_A320.csv', 'Fri0615PMMST_B737.csv', 'Fri0619PMMST_B738.csv', 'Fri0636PMMST_A320.csv', 'Fri0710AMMST_B737.csv', 'Fri0750PMMST_B737.csv', 'Fri0800AMMST_CL60.csv', 'Fri0820AMMST_B738.csv', 'Fri0825AMMST_A21N.csv', 'Fri0900PMMST_B737.csv', 'Fri0910AMMST_B738.csv', 'Fri0915AMMST_SH36.csv', 'Fri0940PMMST_A21N.csv', 'Fri0945PMMST_A21N.csv', 'Fri1015AMMST_B38M.csv', 'Fri1140AMMST_B38M.csv', 'Fri1152AMMST_B38M.csv', 'Fri1255PMMST_B38M.csv', 'Sat0213PMMST_A320.csv', 'Sat0305PMMST_B737.csv', 'Sat0313PMMST_A321.csv', 'Sat0445PMMST_B38M.csv', 'Sat0619PMMST_B38M.csv', 'Sat0642PMMST_A20N.csv', 'Sat0718PMMST_A319.csv', 'Sat0735AMMST_B38M.csv', 'Sat0750PMMST_B38M.csv', 'Sat0818PMMST_A319.csv', 'Sat0825AMMST_A21N.csv', 'Sat0900AMMST_B38M.csv', 'Sat0940PMMST_A20N.csv', 'Sat0940PMMST_A21N.csv', 'Sat1049PMMST_A320.csv', 'Sat1120AMMST_B38M.csv', 'Sat1125PMMST_B38M.csv', 'Sat1152AMMST_B738.csv', 'Sat1220PMMST_A20N.csv', 'Sun0130PMMST_A20N.csv', 'Sun0200PMMST_A321.csv', 'Sun0235PMMST_B738.csv', 'Sun0420PMMST_B737.csv', 'Sun0505PMMST_B738.csv', 'Sun0545AMMST_B737.csv', 'Sun0725AMMST_A21N.csv', 'Sun0740AMMST_B738.csv', 'Sun0835AMMST_B38M.csv', 'Sun0940AMMST_B38M.csv', 'Sun1030AMMST_B38M.csv', 'Sun1032AMMST_B738.csv', 'Sun1105AMMST_A20N.csv', 'Sun1130AMMST_B38M.csv', 'Sun1255PMMST_B38M.csv', 'Thu0100PMMST_B738.csv', 'Thu0230PMMST_A20N.csv', 'Thu0305PMMST_B738.csv', 'Thu0313PMMST_A321.csv', 'Thu0430PMMST_A319.csv', 'Thu0510PMMST_B738.csv', 'Thu0530PMMST_A319.csv', 'Thu0610AMMST_B737.csv', 'Thu0615PMMST_B737.csv', 'Thu0619PMMST_B38M.csv', 'Thu0636PMMST_A20N.csv', 'Thu0715AMMST_B737.csv', 'Thu0720AMMST_B38M.csv', 'Thu0725AMMST_A21N.csv', 'Thu0750PMMST_B737.csv', 'Thu0810AMMST_B738.csv', 'Thu0815AMMST_CL35.csv', 'Thu0820AMMST_B38M.csv', 'Thu0825AMMST_A21N.csv', 'Thu0910AMMST_B738.csv', 'Thu0915AMMST_B38M.csv', 'Thu0915AMMST_SH36.csv', 'Thu0930PMMST_B738.csv', 'Thu0940PMMST_A21N.csv', 'Thu0945PMMST_A20N.csv', 'Thu1015AMMST_B738.csv', 'Thu1032AMMST_B38M.csv', 'Thu1040AMMST_B38M.csv', 'Thu1140AMMST_B38M.csv', 'Thu1152AMMST_B38M.csv', 'Thu1210AMMST_B738.csv', 'Thu1211PMMST_A20N.csv', 'Wed0149PMMST_A20N.csv', 'Wed0200PMMST_A321.csv', 'Wed0200PMMST_B737.csv', 'Wed0306PMMST_CL60.csv', 'Wed0335PMMST_B737.csv', 'Wed0400PMMST_C25C.csv', 'Wed0440PMMST_B738.csv', 'Wed0505PMMST_B738.csv', 'Wed0517PMMST_A20N.csv', 'Wed0521PMMST_A20N.csv', 'Wed0550PMMST_B738.csv', 'Wed0630AMMST_B38M.csv', 'Wed0725AMMST_A21N.csv', 'Wed0730PMMST_B38M.csv', 'Wed0740AMMST_B738.csv', 'Wed0824PMMST_A21N.csv', 'Wed0840PMMST_B738.csv', 'Wed0845PMMST_A20N.csv', 'Wed0910AMMST_B38M.csv', 'Wed0915AMMST_SH36.csv', 'Wed1032AMMST_B38M.csv', 'Wed1040AMMST_B738.csv', 'Wed1210PMMST_A321.csv', 'Wed1245PMMST_B38M.csv']
# Processing Fri0213PMMST_A20N.csv and Fri0213PMMST_A20N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0213PMMST_A20N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0213PMMST_A20N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 04:14:00 PM    Left Gate (PHX) @ Friday 02...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 14 minutes       NaN        NaN
# 4  Fri 04:28:36 PM    Departure (PHX) @ Friday 02...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KSDL)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 04:28:36 PM   33.4311  -112.0217    270  147.0  169.0  1,600    1,600
# 6  Fri 04:28:52 PM   33.4311  -112.0346    270  155.0  178.0  2,125    2,125
# 7  Fri 04:29:08 PM   33.4311  -112.0500    270  178.0  205.0  2,475    2,475
# 8  Fri 04:29:24 PM   33.4310  -112.0673    270  200.0  230.0  2,900    2,900
# 9  Fri 04:29:40 PM   33.4311  -112.0846    271  221.0  254.0  3,375    3,375
# Original Flight Altitude vs Time graph:
# Processing Fri0305PMMST_B738.csv and Fri0305PMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0305PMMST_B738.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0305PMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 05:19:55 PM    Departure (PHX) @ Friday 03...       NaN        NaN
# 2                                    Fri 05:19:55 PM   33.4311  -112.0286
# 3                                    Fri 05:20:11 PM   33.4308  -112.0444
# 4                                    Fri 05:20:27 PM   33.4310  -112.0623
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KPHX)    NaN    NaN    NaN
# 2                       270  177.0  204.0  1,450
# 3                       269  178.0  205.0  2,175
# 4                       271  200.0  230.0  2,675
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Fri 05:19:55 PM   33.4311  -112.0286    270  177.0  204.0  1,450    1,450
# 3  Fri 05:20:11 PM   33.4308  -112.0444    269  178.0  205.0  2,175    2,175
# 4  Fri 05:20:27 PM   33.4310  -112.0623    271  200.0  230.0  2,675    2,675
# 5  Fri 05:20:43 PM   33.4314  -112.0812    272  220.0  253.0  3,125    3,125
# 6  Fri 05:21:13 PM   33.4330  -112.1181    273  240.0  276.0  4,250    4,250
# Original Flight Altitude vs Time graph:
# Processing Fri0313PMMST_A321.csv and Fri0313PMMST_A321_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0313PMMST_A321.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0313PMMST_A321_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 05:10:00 PM    Left Gate (PHX) @ Friday 03...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 16 minutes       NaN        NaN
# 4  Fri 05:26:42 PM    Departure (PHX) @ Friday 03...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KDVT)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 05:26:42 PM   33.4311  -112.0276    269  162.0  186.0  1,675    1,675
# 6  Fri 05:26:58 PM   33.4313  -112.0438    272  168.0  193.0  2,375    2,375
# 7  Fri 05:27:14 PM   33.4317  -112.0594    272  181.0  208.0  2,900    2,900
# 8  Fri 05:27:30 PM   33.4322  -112.0744    273  193.0  222.0  3,300    3,300
# 9  Fri 05:27:46 PM   33.4332  -112.0944    273  211.0  243.0  3,675    3,675
# Original Flight Altitude vs Time graph:
# Processing Fri0510PMMST_B38M.csv and Fri0710AMMST_B737_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0510PMMST_B38M.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0710AMMST_B737_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 07:13:00 PM    Left Gate (PHX) @ Friday 05...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 21 minutes       NaN        NaN
# 4  Fri 07:34:40 PM    Departure (PHX) @ Friday 05...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KDVT)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 07:34:40 PM   33.4309  -112.0259    269  161.0  185.0  1,575    1,575
# 6  Fri 07:34:56 PM   33.4310  -112.0405    272  170.0  196.0  2,075    2,075
# 7  Fri 07:35:12 PM   33.4317  -112.0567    273  184.0  212.0  2,575    2,575
# 8  Fri 07:35:28 PM   33.4326  -112.0735    273  204.0  235.0  2,875    2,875
# 9  Fri 07:35:44 PM   33.4333  -112.0910    273  224.0  258.0  3,175    3,175
# Original Flight Altitude vs Time graph:
# Processing Fri0527PMMST_A320.csv and Fri0800AMMST_CL60_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0527PMMST_A320.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0800AMMST_CL60_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 07:23:00 PM    Left Gate (PHX) @ Friday 05...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 14 minutes       NaN        NaN
# 4  Fri 07:37:41 PM    Departure (PHX) @ Friday 05...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 07:37:41 PM   33.4309  -112.0305    268  160.0  184.0  1,775    1,775
# 6  Fri 07:37:57 PM   33.4308  -112.0444    270  158.0  182.0  2,450    2,450
# 7  Fri 07:38:13 PM   33.4311  -112.0598    273  187.0  215.0  2,725    2,725
# 8  Fri 07:38:29 PM   33.4320  -112.0783    274  210.0  242.0  3,025    3,025
# 9  Fri 07:38:45 PM   33.4329  -112.0979    273  229.0  264.0  3,350    3,350
# Original Flight Altitude vs Time graph:
# Processing Fri0615PMMST_B737.csv and Fri0820AMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0615PMMST_B737.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0820AMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 09:11:20 PM    Departure (PHX) @ Friday 07...       NaN        NaN
# 2                                    Fri 09:11:20 PM   33.4310  -111.9985
# 3                                    Fri 09:11:36 PM   33.4310  -111.9854
# 4                                    Fri 09:11:52 PM   33.4316  -111.9697
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KFFZ)    NaN    NaN    NaN
# 2                        91  158.0  182.0  1,275
# 3                        89  161.0  185.0  1,950
# 4                        86  175.0  201.0  2,500
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Fri 09:11:20 PM   33.4310  -111.9985     91  158.0  182.0  1,275    1,275
# 3  Fri 09:11:36 PM   33.4310  -111.9854     89  161.0  185.0  1,950    1,950
# 4  Fri 09:11:52 PM   33.4316  -111.9697     86  175.0  201.0  2,500    2,500
# 5  Fri 09:12:08 PM   33.4324  -111.9549     86  199.0  229.0  2,800    2,800
# 6  Fri 09:12:24 PM   33.4336  -111.9365     86  216.0  249.0  3,275    3,275
# Original Flight Altitude vs Time graph:
# Processing Fri0619PMMST_B738.csv and Fri0825AMMST_A21N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0619PMMST_B738.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0825AMMST_A21N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 08:49:57 PM    Departure (PHX) @ Friday 06...       NaN        NaN
# 2                                    Fri 08:49:57 PM   33.4312  -111.9954
# 3                                    Fri 08:50:13 PM   33.4314  -111.9811
# 4                                    Fri 08:50:29 PM   33.4322  -111.9643
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KIWA)    NaN    NaN    NaN
# 2                        89  176.0  203.0  1,400
# 3                        88  173.0  199.0  2,175
# 4                        87  183.0  211.0  2,775
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Fri 08:49:57 PM   33.4312  -111.9954     89  176.0  203.0  1,400    1,400
# 3  Fri 08:50:13 PM   33.4314  -111.9811     88  173.0  199.0  2,175    2,175
# 4  Fri 08:50:29 PM   33.4322  -111.9643     87  183.0  211.0  2,775    2,775
# 5  Fri 08:50:45 PM   33.4332  -111.9479     86  203.0  234.0  3,150    3,150
# 6  Fri 08:51:01 PM   33.4343  -111.9269     87  230.0  265.0  3,550    3,550
# Original Flight Altitude vs Time graph:
# Processing Fri0636PMMST_A320.csv and Fri0910AMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0636PMMST_A320.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0910AMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 08:43:00 PM    Left Gate (PHX) @ Friday 06...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 22 minutes       NaN        NaN
# 4  Fri 09:05:35 PM    Departure (PHX) @ Friday 07...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KSDL)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             92.0                NaN
# 1    PXR  33.433017 -111.970202            333.0                2.0
# 2  JONHH  33.804750 -112.197206            333.0               29.0
# 3  GINKE  33.879042 -112.242842            333.0                6.0
# 4  KARLO  34.291178 -112.497656              2.0               32.0
#
#    Distance Remaining  Distance Flown              Type
# 0                 256               0    Origin Airport
# 1                 257               2  VOR-TAC (NAVAID)
# 2                 230              28   Reporting Point
# 3                 224              34   Reporting Point
# 4                 194              66   Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 09:05:35 PM   33.4313  -111.9918     89  149.0  171.0  1,875    1,875
# 6  Fri 09:05:51 PM   33.4316  -111.9801     88  152.0  175.0  2,475    2,475
# 7  Fri 09:06:07 PM   33.4320  -111.9644     88  167.0  192.0  2,875    2,875
# 8  Fri 09:06:23 PM   33.4324  -111.9494     89  188.0  216.0  3,175    3,175
# 9  Fri 09:06:39 PM   33.4327  -111.9328     89  211.0  243.0  3,375    3,375
# Original Flight Altitude vs Time graph:
# Processing Fri0710AMMST_B737.csv and Fri0915AMMST_SH36_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0710AMMST_B737.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri0915AMMST_SH36_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 09:07:00 AM    Left Gate (PHX) @ Friday 07...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 15 minutes       NaN        NaN
# 4  Fri 09:22:58 AM    Departure (PHX) @ Friday 07...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             92.0                NaN
# 1    PXR  33.433017 -111.970202            333.0                2.0
# 2  JONHH  33.804750 -112.197206            333.0               29.0
# 3  GINKE  33.879042 -112.242842            333.0                6.0
# 4  KARLO  34.291178 -112.497656              2.0               32.0
#
#    Distance Remaining  Distance Flown              Type
# 0                 256               0    Origin Airport
# 1                 257               2  VOR-TAC (NAVAID)
# 2                 230              28   Reporting Point
# 3                 224              34   Reporting Point
# 4                 194              66   Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 09:22:58 AM   33.4408  -111.9940     92  157.0  181.0  1,725    1,725
# 6  Fri 09:23:14 AM   33.4402  -111.9801     94  158.0  182.0  2,350    2,350
# 7  Fri 09:23:30 AM   33.4392  -111.9656     95  176.0  203.0  2,775    2,775
# 8  Fri 09:23:46 AM   33.4383  -111.9500     93  199.0  229.0  3,250    3,250
# 9  Fri 09:24:02 AM   33.4375  -111.9329     93  208.0  239.0  4,075    4,075
# Original Flight Altitude vs Time graph:
# Processing Fri0750PMMST_B737.csv and Fri1015AMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0750PMMST_B737.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri1015AMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:58:00 PM    Left Gate (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 18 minutes       NaN        NaN
# 4  Sat 12:16:06 AM    Departure (PHX) @ Friday 10...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KDVT)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Sat 12:16:06 AM   33.4310  -112.0201    270  165.0  190.0  1,225    1,225
# 6  Sat 12:16:22 AM   33.4313  -112.0353    272  171.0  197.0  1,850    1,850
# 7  Sat 12:16:38 AM   33.4317  -112.0497    272  173.0  199.0  2,500    2,500
# 8  Sat 12:16:54 AM   33.4320  -112.0654    271  195.0  224.0  2,925    2,925
# 9  Sat 12:17:10 AM   33.4325  -112.0846    272  214.0  246.0  3,450    3,450
# Original Flight Altitude vs Time graph:
# Processing Fri0800AMMST_CL60.csv and Fri1140AMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0800AMMST_CL60.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri1140AMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:22:00 AM    Departure (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                                    Fri 11:22:23 AM   33.4310  -111.9986
# 4                                    Fri 11:22:39 AM   33.4311  -111.9827
#
#                Course    kts    mph   feet
# 0                 NaN    NaN    NaN    NaN
# 1  Albuquerque Center    NaN    NaN    NaN
# 2                 NaN    NaN    NaN    NaN
# 3                  91  173.0  199.0  1,200
# 4                  88  176.0  203.0  1,900
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 3  Fri 11:22:23 AM   33.4310  -111.9986     91  173.0  199.0  1,200    1,200
# 4  Fri 11:22:39 AM   33.4311  -111.9827     88  176.0  203.0  1,900    1,900
# 5  Fri 11:22:55 AM   33.4320  -111.9682     85  183.0  211.0  2,475    2,475
# 6  Fri 11:23:11 AM   33.4332  -111.9502     86  202.0  232.0  2,875    2,875
# 7  Fri 11:23:27 AM   33.4341  -111.9320     87  222.0  255.0  3,225    3,225
# Original Flight Altitude vs Time graph:
# Processing Fri0820AMMST_B738.csv and Fri1152AMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0820AMMST_B738.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri1152AMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:22:00 AM    Departure (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                                    Fri 11:22:23 AM   33.4310  -111.9986
# 4                                    Fri 11:22:39 AM   33.4311  -111.9827
#
#                Course    kts    mph   feet
# 0                 NaN    NaN    NaN    NaN
# 1  Albuquerque Center    NaN    NaN    NaN
# 2                 NaN    NaN    NaN    NaN
# 3                  91  173.0  199.0  1,200
# 4                  88  176.0  203.0  1,900
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 3  Fri 11:22:23 AM   33.4310  -111.9986     91  173.0  199.0  1,200    1,200
# 4  Fri 11:22:39 AM   33.4311  -111.9827     88  176.0  203.0  1,900    1,900
# 5  Fri 11:22:55 AM   33.4320  -111.9682     85  183.0  211.0  2,475    2,475
# 6  Fri 11:23:11 AM   33.4332  -111.9502     86  202.0  232.0  2,875    2,875
# 7  Fri 11:23:27 AM   33.4341  -111.9320     87  222.0  255.0  3,225    3,225
# Original Flight Altitude vs Time graph:
# Processing Fri0825AMMST_A21N.csv and Fri1255PMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0825AMMST_A21N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Fri1255PMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 10:49:24 AM    Departure (PHX) @ Friday 08...       NaN        NaN
# 2                                    Fri 10:49:24 AM   33.4311  -111.9914
# 3                                    Fri 10:49:40 AM   33.4318  -111.9753
# 4                                    Fri 10:49:56 AM   33.4326  -111.9595
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KSDL)    NaN    NaN    NaN
# 2                        90  173.0  199.0  1,650
# 3                        86  176.0  203.0  2,425
# 4                        87  187.0  215.0  3,025
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Fri 10:49:24 AM   33.4311  -111.9914     90  173.0  199.0  1,650    1,650
# 3  Fri 10:49:40 AM   33.4318  -111.9753     86  176.0  203.0  2,425    2,425
# 4  Fri 10:49:56 AM   33.4326  -111.9595     87  187.0  215.0  3,025    3,025
# 5  Fri 10:50:12 AM   33.4336  -111.9404     86  213.0  245.0  3,500    3,500
# 6  Fri 10:50:40 AM   33.4354  -111.9061     87  251.0  289.0  4,325    4,325
# Original Flight Altitude vs Time graph:
# Processing Fri0900PMMST_B737.csv and Thu0100PMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0900PMMST_B737.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0100PMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:16:00 PM    Left Gate (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 18 minutes       NaN        NaN
# 4  Fri 11:34:47 PM    Departure (PHX) @ Friday 09...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 11:34:47 PM   33.4310  -112.0209    269  184.0  212.0  1,375    1,375
# 6  Fri 11:35:03 PM   33.4311  -112.0379    272  183.0  211.0  2,450    2,450
# 7  Fri 11:35:19 PM   33.4315  -112.0547    271  200.0  230.0  3,175    3,175
# 8  Fri 11:35:35 PM   33.4320  -112.0730    271  213.0  245.0  4,025    4,025
# 9  Fri 11:35:51 PM   33.4323  -112.0928    271  219.0  252.0  5,050    5,050
# Original Flight Altitude vs Time graph:
# Processing Fri0910AMMST_B738.csv and Thu0230PMMST_A20N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0910AMMST_B738.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0230PMMST_A20N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:04:00 AM    Left Gate (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 12 minutes       NaN        NaN
# 4  Fri 11:16:34 AM    Departure (PHX) @ Friday 09...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 11:16:34 AM   33.4311  -111.9962     89  173.0  199.0  1,300    1,300
# 6  Fri 11:16:50 AM   33.4314  -111.9817     88  175.0  201.0  1,925    1,925
# 7  Fri 11:17:06 AM   33.4321  -111.9651     88  184.0  212.0  2,550    2,550
# 8  Fri 11:17:22 AM   33.4328  -111.9487     87  206.0  237.0  2,825    2,825
# 9  Fri 11:17:38 AM   33.4337  -111.9294     86  227.0  261.0  3,300    3,300
# Original Flight Altitude vs Time graph:
# Processing Fri0915AMMST_SH36.csv and Thu0305PMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0915AMMST_SH36.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0305PMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 12:17:00 PM    Left Gate (PHX) @ Friday 10...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 20 minutes       NaN        NaN
# 4  Fri 12:37:06 PM    Departure (PHX) @ Friday 10...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 12:37:06 PM   33.4310  -112.0008     90  171.0  197.0  1,100    1,100
# 6  Fri 12:37:22 PM   33.4312  -111.9852     88  171.0  197.0  1,700    1,700
# 7  Fri 12:37:38 PM   33.4323  -111.9700     84  176.0  203.0  2,250    2,250
# 8  Fri 12:37:54 PM   33.4330  -111.9545     89  195.0  224.0  2,600    2,600
# 9  Fri 12:38:10 PM   33.4334  -111.9367     88  211.0  243.0  2,950    2,950
# Original Flight Altitude vs Time graph:
# Processing Fri0940PMMST_A21N.csv and Thu0313PMMST_A321_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0940PMMST_A21N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0313PMMST_A321_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 12:42:00 AM    Left Gate (PHX) @ Friday 10...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 12 minutes       NaN        NaN
# 4  Sat 12:54:31 AM    Departure (PHX) @ Friday 10...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KGEU)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Sat 12:54:31 AM   33.4310  -112.0214    270  176.0  203.0  1,250    1,250
# 6  Sat 12:54:47 AM   33.4312  -112.0373    272  178.0  205.0  1,950    1,950
# 7  Sat 12:55:03 AM   33.4320  -112.0547    273  196.0  226.0  2,500    2,500
# 8  Sat 12:55:19 AM   33.4326  -112.0722    272  215.0  247.0  2,975    2,975
# 9  Sat 12:55:35 AM   33.4329  -112.0909    271  232.0  267.0  3,475    3,475
# Original Flight Altitude vs Time graph:
# Processing Fri0945PMMST_A21N.csv and Thu0430PMMST_A319_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri0945PMMST_A21N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0430PMMST_A319_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 11:37:00 PM    Left Gate (PHX) @ Friday 09...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 21 minutes       NaN        NaN
# 4  Fri 11:58:56 PM    Departure (PHX) @ Friday 09...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KCHD)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 11:58:56 PM   33.4310  -112.0232    269  186.0  214.0  1,525    1,525
# 6  Fri 11:59:12 PM   33.4306  -112.0408    270  199.0  229.0  2,475    2,475
# 7  Fri 11:59:28 PM   33.4310  -112.0580    273  208.0  239.0  3,250    3,250
# 8  Fri 11:59:44 PM   33.4318  -112.0766    273  228.0  262.0  3,750    3,750
# 9  Sat 12:00:00 AM   33.4328  -112.0979    273  244.0  281.0  4,275    4,275
# Original Flight Altitude vs Time graph:
# Processing Fri1015AMMST_B38M.csv and Thu0510PMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri1015AMMST_B38M.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0510PMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 12:17:00 PM    Left Gate (PHX) @ Friday 10...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 20 minutes       NaN        NaN
# 4  Fri 12:37:06 PM    Departure (PHX) @ Friday 10...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KPHX)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Fri 12:37:06 PM   33.4310  -112.0008     90  171.0  197.0  1,100    1,100
# 6  Fri 12:37:22 PM   33.4312  -111.9852     88  171.0  197.0  1,700    1,700
# 7  Fri 12:37:38 PM   33.4323  -111.9700     84  176.0  203.0  2,250    2,250
# 8  Fri 12:37:54 PM   33.4330  -111.9545     89  195.0  224.0  2,600    2,600
# 9  Fri 12:38:10 PM   33.4334  -111.9367     88  211.0  243.0  2,950    2,950
# Original Flight Altitude vs Time graph:
# Processing Fri1140AMMST_B38M.csv and Thu0530PMMST_A319_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Fri1140AMMST_B38M.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0530PMMST_A319_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Fri 02:14:34 PM    Departure (PHX) @ Friday 12...       NaN        NaN
# 2                                    Fri 02:14:34 PM   33.4314  -112.0265
# 3                                    Fri 02:14:50 PM   33.4315  -112.0409
# 4                                    Fri 02:15:06 PM   33.4314  -112.0557
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KDVT)    NaN    NaN    NaN
# 2                       271  161.0  185.0  1,550
# 3                       270  167.0  192.0  2,200
# 4                       269  178.0  205.0  2,550
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# ...
# 9  Sat 10:06:09 PM   33.4342  -111.9330     87  217.0  250.0  3,125    3,125
# Original Flight Altitude vs Time graph:
# Processing Sat0818PMMST_A319.csv and Thu0940PMMST_A21N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat0818PMMST_A319.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0940PMMST_A21N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 11:01:42 PM    Departure (PHX) @ Saturday ...       NaN        NaN
# 2                                    Sat 11:01:42 PM   33.4309  -112.0038
# 3                                    Sat 11:01:58 PM   33.4308  -111.9903
# 4                                    Sat 11:02:14 PM   33.4313  -111.9780
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KCHD)    NaN    NaN    NaN
# 2                        92  144.0  166.0  1,450
# 3                        89  141.0  162.0  2,325
# 4                        85  150.0  173.0  3,025
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Sat 11:01:42 PM   33.4309  -112.0038     92  144.0  166.0  1,450    1,450
# 3  Sat 11:01:58 PM   33.4308  -111.9903     89  141.0  162.0  2,325    2,325
# 4  Sat 11:02:14 PM   33.4313  -111.9780     85  150.0  173.0  3,025    3,025
# 5  Sat 11:02:30 PM   33.4324  -111.9655     84  163.0  188.0  3,625    3,625
# 6  Sat 11:02:46 PM   33.4339  -111.9492     84  186.0  214.0  4,175    4,175
# Original Flight Altitude vs Time graph:
# Processing Sat0825AMMST_A21N.csv and Thu0945PMMST_A20N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat0825AMMST_A21N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu0945PMMST_A20N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 10:43:32 AM    Departure (PHX) @ Saturday ...       NaN        NaN
# 2                                    Sat 10:43:32 AM   33.4309  -111.9922
# 3                                    Sat 10:43:48 AM   33.4313  -111.9793
# 4                                    Sat 10:44:04 AM   33.4321  -111.9632
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KIWA)    NaN    NaN    NaN
# 2                        91  160.0  184.0  1,650
# 3                        87  163.0  188.0  2,300
# 4                        86  179.0  206.0  2,875
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Sat 10:43:32 AM   33.4309  -111.9922     91  160.0  184.0  1,650    1,650
# 3  Sat 10:43:48 AM   33.4313  -111.9793     87  163.0  188.0  2,300    2,300
# 4  Sat 10:44:04 AM   33.4321  -111.9632     86  179.0  206.0  2,875    2,875
# 5  Sat 10:44:20 AM   33.4331  -111.9466     86  197.0  227.0  3,350    3,350
# 6  Sat 10:44:36 AM   33.4341  -111.9293     86  218.0  251.0  3,750    3,750
# Original Flight Altitude vs Time graph:
# Processing Sat0900AMMST_B38M.csv and Thu1015AMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat0900AMMST_B38M.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu1015AMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 10:59:00 AM    Left Gate (PHX) @ Saturday ...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 16 minutes       NaN        NaN
# 4  Sat 11:15:04 AM    Departure (PHX) @ Saturday ...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KIWA)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Sat 11:15:04 AM   33.4310  -112.0020     90  160.0  184.0  1,125    1,125
# 6  Sat 11:15:20 AM   33.4311  -111.9874     89  157.0  181.0  1,875    1,875
# 7  Sat 11:15:36 AM   33.4315  -111.9736     88  168.0  193.0  2,400    2,400
# 8  Sat 11:15:52 AM   33.4321  -111.9574     87  188.0  216.0  2,750    2,750
# 9  Sat 11:16:08 AM   33.4329  -111.9393     87  208.0  239.0  3,150    3,150
# Original Flight Altitude vs Time graph:
# Processing Sat0940PMMST_A20N.csv and Thu1140AMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat0940PMMST_A20N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu1140AMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sun 12:34:20 AM    Departure (PHX) @ Saturday ...       NaN        NaN
# 2                                    Sun 12:34:20 AM   33.4311  -112.0034
# 3                                    Sun 12:34:36 AM   33.4313  -111.9908
# 4                                    Sun 12:34:52 AM   33.4318  -111.9786
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KSDL)    NaN    NaN    NaN
# 2                        89  148.0  170.0  1,300
# 3                        88  141.0  162.0  2,075
# 4                        86  155.0  178.0  2,575
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Sun 12:34:20 AM   33.4311  -112.0034     89  148.0  170.0  1,300    1,300
# 3  Sun 12:34:36 AM   33.4313  -111.9908     88  141.0  162.0  2,075    2,075
# 4  Sun 12:34:52 AM   33.4318  -111.9786     86  155.0  178.0  2,575    2,575
# 5  Sun 12:35:08 AM   33.4327  -111.9647     86  178.0  205.0  2,925    2,925
# 6  Sun 12:35:24 AM   33.4338  -111.9456     86  207.0  238.0  3,450    3,450
# Original Flight Altitude vs Time graph:
# Processing Sat0940PMMST_A21N.csv and Thu1152AMMST_B38M_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat0940PMMST_A21N.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu1152AMMST_B38M_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 11:41:00 PM    Left Gate (PHX) @ Saturday ...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 27 minutes       NaN        NaN
# 4  Sun 12:08:03 AM    Departure (PHX) @ Saturday ...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KFFZ)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Sun 12:08:03 AM   33.4311  -111.9956     90  164.0  189.0  1,400    1,400
# 6  Sun 12:08:19 AM   33.4313  -111.9828     87  157.0  181.0  2,275    2,275
# 7  Sun 12:08:35 AM   33.4320  -111.9681     86  166.0  191.0  2,875    2,875
# 8  Sun 12:08:51 AM   33.4332  -111.9521     85  188.0  216.0  3,375    3,375
# 9  Sun 12:09:07 AM   33.4342  -111.9365     86  207.0  238.0  3,800    3,800
# Original Flight Altitude vs Time graph:
# Processing Sat1049PMMST_A320.csv and Thu1210AMMST_B738_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat1049PMMST_A320.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu1210AMMST_B738_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sun 12:54:00 AM    Left Gate (PHX) @ Saturday ...       NaN        NaN
# 2                                                NaN       NaN        NaN
# 3                              Taxi Time: 10 minutes       NaN        NaN
# 4  Sun 01:04:41 AM    Departure (PHX) @ Saturday ...       NaN        NaN
#
#                      Course  kts  mph feet
# 0                       NaN  NaN  NaN  NaN
# 1                   Airline  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN
# 3                       NaN  NaN  NaN  NaN
# 4  FlightAware ADS-B (KCHD)  NaN  NaN  NaN
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 5  Sun 01:04:41 AM   33.4310  -112.0018     90  155.0  178.0  1,275    1,275
# 6  Sun 01:04:57 AM   33.4310  -111.9886     90  152.0  175.0  1,975    1,975
# 7  Sun 01:05:13 AM   33.4314  -111.9728     88  164.0  189.0  2,550    2,550
# 8  Sun 01:05:29 AM   33.4321  -111.9579     86  189.0  217.0  2,850    2,850
# 9  Sun 01:05:45 AM   33.4330  -111.9411     86  208.0  239.0  3,225    3,225
# Original Flight Altitude vs Time graph:
# Processing Sat1120AMMST_B38M.csv and Thu1211PMMST_A20N_WAYPOINTS.csv...
# Loading data from scraped_data_KPHX_KLAS\Sat1120AMMST_B38M.csv
# Loading data from scraped_waypoints_KPHX_KLAS\Thu1211PMMST_A20N_WAYPOINTS.csv
# Flight Data:
#                                           Time (EST)  Latitude  Longitude  \
# 0                                                NaN       NaN        NaN
# 1  Sat 01:39:28 PM    Departure (PHX) @ Saturday ...       NaN        NaN
# 2                                    Sat 01:39:28 PM   33.4310  -111.9929
# 3                                    Sat 01:39:44 PM   33.4314  -111.9781
# 4                                    Sat 01:40:00 PM   33.4323  -111.9616
#
#                      Course    kts    mph   feet
# 0                       NaN    NaN    NaN    NaN
# 1  FlightAware ADS-B (KPHX)    NaN    NaN    NaN
# 2                        90  164.0  189.0  1,525
# 3                        87  173.0  199.0  2,075
# 4                        86  193.0  222.0  2,325
# Waypoints:
#     Name   Latitude   Longitude  Outbound Course  Distance this Leg  \
# 0   KPHX  33.434278 -112.011583             89.0                NaN
# 1  SPRKY  33.435833 -111.891056             12.0                7.0
# 2  GOALY  33.651556 -111.836611            352.0               15.0
# 3  JOLAR  33.733472 -111.850306            306.0                6.0
# 4  ZEPER  34.027583 -112.334361            320.0               34.0
#
#    Distance Remaining  Distance Flown             Type
# 0                 256               0   Origin Airport
# 1                 260               7         Waypoint
# 2                 252              18         Waypoint
# 3                 248              23         Waypoint
# 4                 214              45  Reporting Point
#         Time (EST)  Latitude  Longitude Course    kts    mph   feet feet_str
# 2  Sat 01:39:28 PM   33.4310  -111.9929     90  164.0  189.0  1,525    1,525
# 3  Sat 01:39:44 PM   33.4314  -111.9781     87  173.0  199.0  2,075    2,075
# 4  Sat 01:40:00 PM   33.4323  -111.9616     86  193.0  222.0  2,325    2,325
# 5  Sat 01:40:16 PM   33.4331  -111.9442     88  212.0  244.0  2,725    2,725
# 6  Sat 01:40:32 PM   33.4334  -111.9256     89  229.0  264.0  3,225    3,225
# Original Flight Altitude vs Time graph:
